# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from scipy.stats import boxcox
warnings.filterwarnings('ignore')

df = pd.read_csv("air_traffic_data.csv", sep=';')
df.head()
# Out:
#   Activity Period,Operating Airline,Operating Airline IATA Code,Published Airline,Published Airline IATA Code,GEO Summary,GEO Region,Activity Type Code,Price Category Code,Terminal,Boarding Area,Passenger Count,Adjusted Activity Type Code,Adjusted Passenger Count,Year,Month
# 0  200507,ATA Airlines,TZ,ATA Airlines,TZ,Domesti...
# 1  200507,ATA Airlines,TZ,ATA Airlines,TZ,Domesti...
# 2  200507,ATA Airlines,TZ,ATA Airlines,TZ,Domesti...
# 3  200507,Air Canada ,AC,Air Canada ,AC,Internati...
# 4  200507,Air Canada ,AC,Air Canada ,AC,Internati...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15007 entries, 0 to 15006
# Data columns (total 1 columns):
#  #   Column                                                                                                                                                                                                                                                                            Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                                                                                            --------------  -----
#  0   Activity Period,Operating Airline,Operating Airline IATA Code,Published Airline,Published Airline IATA Code,GEO Summary,GEO Region,Activity Type Code,Price Category Code,Terminal,Boarding Area,Passenger Count,Adjusted Activity Type Code,Adjusted Passenger Count,Year,Month  15007 non-null  object
# dtypes: object(1)
# memory usage: 117.4+ KB

# %%
df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15007 entries, 0 to 15006
# Data columns (total 1 columns):
#  #   Column                                                                                                                                                                                                                                                                            Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                                                                                            --------------  -----
#  0   Activity Period,Operating Airline,Operating Airline IATA Code,Published Airline,Published Airline IATA Code,GEO Summary,GEO Region,Activity Type Code,Price Category Code,Terminal,Boarding Area,Passenger Count,Adjusted Activity Type Code,Adjusted Passenger Count,Year,Month  15007 non-null  object
# dtypes: object(1)
# memory usage: 2.7 MB

# %%
df.describe(include='all').T
# Out:
#                                                     count unique  \
# Activity Period,Operating Airline,Operating Air...  15007  15007
#
#                                                                                                   top  \
# Activity Period,Operating Airline,Operating Air...  200507,ATA Airlines,TZ,ATA Airlines,TZ,Domesti...
#
#                                                    freq
# Activity Period,Operating Airline,Operating Air...    1

# %%
df.isnull().sum()
# Out:
# Activity Period,Operating Airline,Operating Airline IATA Code,Published Airline,Published Airline IATA Code,GEO Summary,GEO Region,Activity Type Code,Price Category Code,Terminal,Boarding Area,Passenger Count,Adjusted Activity Type Code,Adjusted Passenger Count,Year,Month    0
# dtype: int64

# %%
#haz un mapa de calor para ver los valores nulos
sns.heatmap(df.isnull(), cbar=False)
# Out:
# <AxesSubplot: >
